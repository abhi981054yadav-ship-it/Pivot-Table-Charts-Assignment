# %% [markdown]
# #Pivot Table & Charts  Assignment

# %% [markdown]
# 1. What is the purpose of a PivotTable in Excel?

# %% [markdown]
#  -> Pivort table is a very helpful tool in excel It helps to find total, average, count quickly it saves time and efforts and used to summarize and analyze data easily.
#  We can see data by category like Region or Product.
# It saves time and no need to write big formulas.
#
# * For EX. We can find total sales by region with using pivort table.

# %% [markdown]
# 2. Create a PivotTable to show Total Sales by Region.

# %% [markdown]
#  -> ![Screenshot 2026-04-07 083947.png](data:image/png;base64,...)
#
#  also we can check Answer 2 sheet in excel file

# %% [markdown]
# 3. Apply Conditional Formatting to highlight sales greater than 400.

# %% [markdown]
#   ->  Conditional formating sales greater than 400 is higligheted in blue colour.
#
#   ![Screenshot 2026-04-07 084551.png](data:image/png;base64,...)
#   Also can see Answer 3 excel sheet.

# %% [markdown]
# 4. Explain the difference between Sorting and Filtering with an example from this dataset.

# %% [markdown]
#  -> The difference between Sorting and Filtering is:
#   * Sorting
#
#     Sorting means arranging data.
#
#     We can arrange data in ascendind and  descending order like smallest to  largest or high to low, it help in arrange data in order.
#      for ex. we can arrange data smallest to largest quantity
#      ![Screenshot 2026-04-07 123834.png](data:image/png;base64,...)
#
#   * Filtering
#
#     Filtering means showing selected data only. It will only show selected data only and it help in find similar data like   we can select on mango quantity then it only shows mango quantity.
#     for ex.only mango
#     ![Screenshot 2026-04-07 130853.png](data:image/png;base64,...)
#
#
#     from this data if we want only mango data we simply apply filter  on product and select mango.
#
#     ![Screenshot 2026-04-07 130839.png](data:image/png;base64,...)

# %% [markdown]
# 5.Create a PivotChart showing Monthly Sales Trend.

# %% [markdown]
# ![Screenshot 2026-04-07 135008.png](data:image/png;base64,...) And also check answer 5 sheet in wookbook

# %% [markdown]
# 6. Use a Slicer to filter data by Product and observe changes in sales

# %% [markdown]
# ![Screenshot 2026-04-07 155459.png](data:image/png;base64,...)![Screenshot 2026-04-07 155344.png](data:image/png;base64,...)![Screenshot 2026-04-07 155416.png](data:image/png;base64,...)
#
# The most selling product is mangoes than oranges and last apples

# %% [markdown]
# 7. Why are Dashboards important for decision-making in business analysis?

# %% [markdown]
# -> Dashboard shows all data in one place. It is like car dashboard where you can see all important information related to car simply like that dashboards are short and collection of all impotant information at one palce. It is easy to understand and helps in decision making. It shows all busniess related information at one place like sales, product, profit and loss as per data.
# It helps in decision making to management and employee.

# %% [markdown]
# 8. Create a Dashboard that includes:
#
#   * Sales by Region (PivotTable + Chart)
#
#  * Product Filter (Slicer)
#
#   * Monthly Trend (Line Chart)

# %% [markdown]
# Also check answer 8 sheet in workbook
#
# ![Screenshot 2026-04-08 135847.png](data:image/png;base64,...)

# %% [markdown]
# 9. Group dates in the PivotTable into Months and calculate the average sales per month

# %% [markdown]
# The average sales per month is 1138.16667 from JAN to JUN
#  and also check answer 9 sheet in workbook.
#
#
# ![Screenshot 2026-04-08 131949.png](data:image/png;base64,...)

# %% [markdown]
# 10. Combine Apples and Oranges into one group called Fruits and compare its sales with other products.

# %% [markdown]
#   Also can check Answer 10 sheet in workbook
#
#  ![Screenshot 2026-04-08 135328.png](data:image/png;base64,...)
